# %% [markdown]
# <a href="https://colab.research.google.com/github/Morsalina/diabetes_prediction/blob/main/diabetes_prediction_SVM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
